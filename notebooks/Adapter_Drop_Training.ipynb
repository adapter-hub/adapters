# %% [markdown]
# # Training a `Robust' Adapter with AdapterDrop
#
# This notebook extends our quickstart adapter training notebook to illustrate how we can use AdapterDrop
# to robustly train an adapter, i.e. adapters that allow us to dynmically dropp layers for faster multi-task inference.
# Please have a look at the original adapter training notebook for more details on the setup.

# %% [markdown]
# ## Installation
#
# First, let's install the required libraries:

# %%
# !pip install git+https://github.com/Adapter-Hub/adapter-transformers.git
# !pip install datasets
# Out:
# Collecting git+https://github.com/Adapter-Hub/adapter-transformers.git
#   Cloning https://github.com/Adapter-Hub/adapter-transformers.git to /private/var/folders/0y/ybdccp1j41142qkg4cs84snm0000gn/T/pip-req-build-k2vvz3_x
#   Running command git clone -q https://github.com/Adapter-Hub/adapter-transformers.git /private/var/folders/0y/ybdccp1j41142qkg4cs84snm0000gn/T/pip-req-build-k2vvz3_x
# done
# done
# done
# Collecting sentencepiece==0.1.91
#   Downloading sentencepiece-0.1.91-cp37-cp37m-macosx_10_6_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.8 MB/s eta 0:00:01
# Requirement already satisfied: sacremoses in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from adapter-transformers==1.1.0) (0.0.43)
# Requirement already satisfied: filelock in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from adapter-transformers==1.1.0) (3.0.12)
# Collecting tokenizers==0.9.3
#   Downloading tokenizers-0.9.3-cp37-cp37m-macosx_10_11_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from adapter-transformers==1.1.0) (20.8)
# Requirement already satisfied: regex!=2019.12.17 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from adapter-transformers==1.1.0) (2020.11.13)
# Requirement already satisfied: requests in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from adapter-transformers==1.1.0) (2.25.1)
# Requirement already satisfied: numpy in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from adapter-transformers==1.1.0) (1.19.2)
# Requirement already satisfied: protobuf in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from adapter-transformers==1.1.0) (3.13.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from adapter-transformers==1.1.0) (4.54.1)
# Requirement already satisfied: joblib in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from sacremoses->adapter-transformers==1.1.0) (1.0.0)
# Requirement already satisfied: click in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from sacremoses->adapter-transformers==1.1.0) (7.1.2)
# Requirement already satisfied: six in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from sacremoses->adapter-transformers==1.1.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from packaging->adapter-transformers==1.1.0) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from requests->adapter-transformers==1.1.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from requests->adapter-transformers==1.1.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from requests->adapter-transformers==1.1.0) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from requests->adapter-transformers==1.1.0) (2.10)
# Requirement already satisfied: setuptools in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from protobuf->adapter-transformers==1.1.0) (47.1.1.post20200604)
# Building wheels for collected packages: adapter-transformers
# done
#   Created wheel for adapter-transformers: filename=adapter_transformers-1.1.0-py3-none-any.whl size=1326807 sha256=3e530008a30e99fda442fe92fc8386632b9f943cf03e986517c4a0fe3dda5ddb
#   Stored in directory: /private/var/folders/0y/ybdccp1j41142qkg4cs84snm0000gn/T/pip-ephem-wheel-cache-4ottnpj_/wheels/60/0e/d5/86e64fef3085f149b504f48af9ca6e8f6da427f42da9b4bbe5
# Successfully built adapter-transformers
# Installing collected packages: sentencepiece, tokenizers, adapter-transformers
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.94
#     Uninstalling sentencepiece-0.1.94:
#       Successfully uninstalled sentencepiece-0.1.94
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.9.4
#     Uninstalling tokenizers-0.9.4:
#       Successfully uninstalled tokenizers-0.9.4
# Successfully installed adapter-transformers-1.1.0 sentencepiece-0.1.91 tokenizers-0.9.3
# Collecting datasets
#   Downloading datasets-1.1.3-py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 7.8 MB/s eta 0:00:01
# Collecting xxhash
#   Downloading xxhash-2.0.0-cp37-cp37m-macosx_10_6_intel.whl (68 kB)
#      |████████████████████████████████| 68 kB 6.5 MB/s eta 0:00:011
# Collecting dill
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 6.0 MB/s eta 0:00:011
# Collecting multiprocess
#   Downloading multiprocess-0.70.11.1-py37-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 7.8 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-1.2.0-cp37-cp37m-macosx_10_9_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 6.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from datasets) (1.19.2)
# Collecting pyarrow>=0.17.1
#   Downloading pyarrow-2.0.0-cp37-cp37m-macosx_10_13_x86_64.whl (13.4 MB)
#      |████████████████████████████████| 13.4 MB 7.0 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19.0 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from datasets) (2.25.1)
# Collecting tqdm<4.50.0,>=4.27
#   Downloading tqdm-4.49.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 6.3 MB/s eta 0:00:011
# Collecting pytz>=2017.3
#   Downloading pytz-2020.5-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 7.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied: six>=1.5 in /Users/andy/anaconda3/envs/adapter-hub/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: xxhash, dill, multiprocess, pytz, pandas, pyarrow, tqdm, datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.54.1
#     Uninstalling tqdm-4.54.1:
#       Successfully uninstalled tqdm-4.54.1
# Successfully installed datasets-1.1.3 dill-0.3.3 multiprocess-0.70.11.1 pandas-1.2.0 pyarrow-2.0.0 pytz-2020.5 tqdm-4.49.0 xxhash-2.0.0

# %%
from datasets import load_dataset
from transformers import RobertaTokenizer

dataset = load_dataset("rotten_tomatoes")
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")

def encode_batch(batch):
  """Encodes a batch of input data using the model tokenizer."""
  return tokenizer(batch["text"], max_length=80, truncation=True, padding="max_length")

# Encode the input data
dataset = dataset.map(encode_batch, batched=True)
# The transformers model expects the target class column to be named "labels"
dataset.rename_column_("label", "labels")
# Transform to pytorch tensors and only output the required columns
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# OSError: [Errno 64] Host is down
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     181             raise NewConnectionError(
# --> 182                 self, "Failed to establish a new connection: %s" % e
#     183             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fd64fb4f390>: Failed to establish a new connection: [Errno 64] Host is down
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     572         if new_retry.is_exhausted():
# --> 573             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     574
#
# MaxRetryError: HTTPSConnectionPool(host='s3.amazonaws.com', port=443): Max retries exceeded with url: /datasets.huggingface.co/datasets/datasets/rotten_tomatoes/rotten_tomatoes.py (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fd64fb4f390>: Failed to establish a new connection: [Errno 64] Host is down'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-3545a7210bbc> in <module>
#       2 from transformers import RobertaTokenizer
#       3
# ----> 4 dataset = load_dataset("rotten_tomatoes")
#       5 tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
#       6
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, save_infos, script_version, **config_kwargs)
#     587     # Download/copy dataset processing script
#     588     module_path, hash = prepare_module(
# --> 589         path, script_version=script_version, download_config=download_config, download_mode=download_mode, dataset=True
#     590     )
#     591
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/datasets/load.py in prepare_module(path, script_version, download_config, download_mode, dataset, force_local_path, **download_kwargs)
#     261     else:
#     262         # Try github (canonical datasets/metrics) and then S3 (users datasets/metrics)
# --> 263         head_hf_s3(path, filename=name, dataset=dataset)
#     264         script_version = str(script_version) if script_version is not None else None
#     265         file_path = hf_github_url(path=path, name=name, dataset=dataset, version=script_version)
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/datasets/utils/file_utils.py in head_hf_s3(identifier, filename, use_cdn, dataset)
#     198
#     199 def head_hf_s3(identifier: str, filename: str, use_cdn=False, dataset=True) -> requests.Response:
# --> 200     return http_head(hf_bucket_url(identifier=identifier, filename=filename, use_cdn=use_cdn, dataset=dataset))
#     201
#     202
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/datasets/utils/file_utils.py in http_head(url, proxies, user_agent, cookies, allow_redirects, timeout)
#     401     headers = {"user-agent": get_datasets_user_agent(user_agent=user_agent)}
#     402     response = requests.head(
# --> 403         url, proxies=proxies, headers=headers, cookies=cookies, allow_redirects=allow_redirects, timeout=timeout
#     404     )
#     405     return response
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/requests/api.py in head(url, **kwargs)
#     102
#     103     kwargs.setdefault('allow_redirects', False)
# --> 104     return request('head', url, **kwargs)
#     105
#     106
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/adapter-hub/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='s3.amazonaws.com', port=443): Max retries exceeded with url: /datasets.huggingface.co/datasets/datasets/rotten_tomatoes/rotten_tomatoes.py (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fd64fb4f390>: Failed to establish a new connection: [Errno 64] Host is down'))

# %% [markdown]
# ## Training

# %%
from transformers import RobertaConfig, RobertaModelWithHeads, AdapterType

config = RobertaConfig.from_pretrained(
    "roberta-base",
    num_labels=2,
    id2label={ 0: "👎", 1: "👍"},
)
model = RobertaModelWithHeads.from_pretrained(
    "roberta-base",
    config=config,
)

# Add a new adapter
model.add_adapter("rotten_tomatoes", AdapterType.text_task)
# Add a matching classification head
model.add_classification_head("rotten_tomatoes", num_labels=2)
# Activate the adapter
model.train_adapter("rotten_tomatoes")

# %% [markdown]
# To dynamically drop adapter layers during training, we make use of HuggingFace's `TrainerCallback'.

# %%
import numpy as np
from transformers import TrainingArguments, Trainer, EvalPrediction, TrainerCallback

class AdapterDropTrainerCallback(TrainerCallback):
  def on_step_begin(self, args, state, control, **kwargs):
    skip_layers = list(range(np.random.randint(0, 11)))
    kwargs['model'].set_active_adapters("sst-2", skip_layers=skip_layers)

  def on_evaluate(self, args, state, control, **kwargs):
    # Deactivate skipping layers during evaluation (otherwise it would use the
    # previous randomly chosen skip_layers and thus yield results not comparable
    # across different epochs)
    kwargs['model'].set_active_adapters("sst-2", skip_layers=None)


training_args = TrainingArguments(
    learning_rate=1e-4,
    num_train_epochs=6,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    logging_steps=200,
    output_dir="./training_output",
    overwrite_output_dir=True,
)

def compute_accuracy(p: EvalPrediction):
  preds = np.argmax(p.predictions, axis=1)
  return {"acc": (preds == p.label_ids).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    compute_metrics=compute_accuracy,
)

trainer.add_callback(AdapterDropTrainerCallback())

# %% [markdown]
# We can now train and evaluate our robustly trained adapter!

# %%
trainer.train()
trainer.evaluate()
